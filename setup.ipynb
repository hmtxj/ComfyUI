# %% [markdown]
# # ComfyUI - AMD ROCm 一键部署

# %%
# 安装 PyTorch ROCm 版本
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/rocm6.0

# %%
# 克隆 ComfyUI
import os
if not os.path.exists('/workspace/ComfyUI'):
    # !git clone https://github.com/comfyanonymous/ComfyUI.git /workspace/ComfyUI
# %cd /workspace/ComfyUI

# 安装依赖
# !pip install -r requirements.txt

# %%
# 安装常用自定义节点
# %cd /workspace/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager.git
# !cd ComfyUI-Manager && pip install -r requirements.txt

# %%
# 下载模型（SD 1.5 示例，按需替换）
import os
os.makedirs('/workspace/ComfyUI/models/checkpoints', exist_ok=True)

# 取消注释你需要的模型：
# SD 1.5
# !wget -c https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors -O /workspace/ComfyUI/models/checkpoints/v1-5-pruned-emaonly.safetensors

# SDXL
# !wget -c https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors -O /workspace/ComfyUI/models/checkpoints/sd_xl_base_1.0.safetensors

print('模型目录：', os.listdir('/workspace/ComfyUI/models/checkpoints'))

# %%
# 验证 GPU
import torch
print(f'PyTorch 版本: {torch.__version__}')
print(f'ROCm 可用: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    print(f'显存: {torch.cuda.get_device_properties(0).total_mem / 1024**3:.1f} GB')

# %%
# 启动 ComfyUI
# %cd /workspace/ComfyUI
# !python main.py --listen 0.0.0.0 --port 8188
